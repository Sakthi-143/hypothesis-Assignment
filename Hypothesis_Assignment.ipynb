# %% [markdown]
# # Question 1

# %% [markdown]
# # minitab file = cutlets.mtw

# %% [markdown]
# 1.A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units. A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level. Please state the assumptions and tests that you carried out to check validity of the assumptions. Cutlets.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm
from scipy.stats import ttest_ind, mannwhitneyu

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8f6affaf-de66-4e75-a7b0-79624988b8ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f6affaf-de66-4e75-a7b0-79624988b8ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data =pd.read_csv('Cutlets.csv')

# %%
data
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
unit_A = pd.Series(data.iloc[:,0])
unit_A
# Out:
# 0     6.8090
# 1     6.4376
# 2     6.9157
# 3     7.3012
# 4     7.4488
# 5     7.3871
# 6     6.8755
# 7     7.0621
# 8     6.6840
# 9     6.8236
# 10    7.3930
# 11    7.5169
# 12    6.9246
# 13    6.9256
# 14    6.5797
# 15    6.8394
# 16    6.5970
# 17    7.2705
# 18    7.2828
# 19    7.3495
# 20    6.9438
# 21    7.1560
# 22    6.5341
# 23    7.2854
# 24    6.9952
# 25    6.8568
# 26    7.2163
# 27    6.6801
# 28    6.9431
# 29    7.0852
# 30    6.7794
# 31    7.2783
# 32    7.1561
# 33    7.3943
# 34    6.9405
# Name: Unit A, dtype: float64

# %%
unit_B =pd.Series(data.iloc[:,1])
unit_B
# Out:
# 0     6.7703
# 1     7.5093
# 2     6.7300
# 3     6.7878
# 4     7.1522
# 5     6.8110
# 6     7.2212
# 7     6.6606
# 8     7.2402
# 9     7.0503
# 10    6.8810
# 11    7.4059
# 12    6.7652
# 13    6.0380
# 14    7.1581
# 15    7.0240
# 16    6.6672
# 17    7.4314
# 18    7.3070
# 19    6.7478
# 20    6.8889
# 21    7.4220
# 22    6.5217
# 23    7.1688
# 24    6.7594
# 25    6.9399
# 26    7.0133
# 27    6.9182
# 28    6.3346
# 29    7.5459
# 30    7.0992
# 31    7.1180
# 32    6.6965
# 33    6.5780
# 34    7.3875
# Name: Unit B, dtype: float64

# %%
t_stat, p_value_t = ttest_ind(data['Unit A'], data['Unit B'])

# %%
p_value=stats.ttest_ind(unit_A,unit_B)
p_value
# Out:
# TtestResult(statistic=0.7228688704678063, pvalue=0.4722394724599501, df=68.0)

# %%
alpha = 0.05
if p_value_t < alpha:
    print("Reject the null hypothesis. There is a significant difference.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference.")
# Out:
# Fail to reject the null hypothesis. There is no significant difference.

# %%
# compare p_value with α = 0.05 (At 5% significance level)

# %% [markdown]
# # Question 2

# %% [markdown]
# # minitab file = LabTAT.mtw

# %% [markdown]
# 2.A hospital wants to determine whether there is any difference in the average Turn Around Time (TAT) of reports of the laboratories on their preferred list. They collected a random sample and recorded TAT for reports of 4 laboratories. TAT is defined as sample collected to report dispatch.
#
# Analyze the data and determine whether there is any difference in average TAT among the different laboratories at 5% significance level.   Minitab File: LabTAT.mtw

# %%
import pandas as pd
import pandas as pd
from scipy.stats import f_oneway
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy as sp

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f44b728c-e157-43cd-9f85-1ebc2a0fa6bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f44b728c-e157-43cd-9f85-1ebc2a0fa6bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('LabTAT.csv')
data
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
data.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
data.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
print(data.head())
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
f_statistic, p_value = f_oneway(data['Laboratory 1'],
                                data['Laboratory 2'],
                                data['Laboratory 3'],
                                data['Laboratory 4'])

# %%
print(f"ANOVA F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# ANOVA F-statistic: 118.70421654401437
# P-value: 2.1156708949992414e-57

# %%
# Compare p-value to the significance level (e.g., 0.05)
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in average TAT among laboratories.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in average TAT among laboratories.")
# Out:
# Reject the null hypothesis. There is a significant difference in average TAT among laboratories.

# %% [markdown]
# # Question 3

# %% [markdown]
# #minitab files = BuyersRatio.mtw

# %% [markdown]
# 3. Sales of products in four different regions is tabulated for males and females. Find if male-female buyer rations are similar across regions.

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-2d59fa61-4738-4729-a685-f1c2aa8c11a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d59fa61-4738-4729-a685-f1c2aa8c11a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('BuyerRatio.csv')
data
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
data.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observed Values  2 non-null      object
#  1   East             2 non-null      int64
#  2   West             2 non-null      int64
#  3   North            2 non-null      int64
#  4   South            2 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 208.0+ bytes

# %%
print(data.columns)
# Out:
# Index(['Observed Values', 'East', 'West', 'North', 'South'], dtype='object')

# %%
observed_values = data['Observed Values']
regions_data = data[['East', 'West', 'North', 'South']]

# %%
chi2, p_value, _, _ = chi2_contingency(regions_data)

# %%
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p_value}")
# Out:
# Chi-square statistic: 1.595945538661058
# P-value: 0.6603094907091882

# %%
# Compare p-value to the significance level (e.g., 0.05)
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is an association between gender and region.")
else:
    print("Fail to reject the null hypothesis. There is no association between gender and region.")
# Out:
# Fail to reject the null hypothesis. There is no association between gender and region.

# %% [markdown]
# # Question 4

# %% [markdown]
# # minitab file = UstomerOrderForm.mtw

# %% [markdown]
# 4. TeleCall uses 4 centers around the globe to process customer order forms. They audit a certain % of the customer order forms. Any error in order form renders it defective and has to be reworked before processing. The manager wants to check whether the defective % varies by centre. Please analyze the data at 5% significance level and help the manager draw appropriate inferences

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-951ff002-206c-4afc-ad53-ac0fcc5d476e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-951ff002-206c-4afc-ad53-ac0fcc5d476e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data =pd.read_csv('Costomer+OrderForm.csv')
data
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Phillippines  300 non-null    object
#  1   Indonesia     300 non-null    object
#  2   Malta         300 non-null    object
#  3   India         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
data.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
data.describe()
# Out:
#        Phillippines   Indonesia       Malta       India
# count           300         300         300         300
# unique            2           2           2           2
# top      Error Free  Error Free  Error Free  Error Free
# freq            271         267         269         280

# %%
print(data.columns)
# Out:
# Index(['Phillippines', 'Indonesia', 'Malta', 'India'], dtype='object')

# %%
# Create a DataFrame with the provided data
data = pd.DataFrame({
    'Country': ['Phillippines', 'Indonesia', 'Malta', 'India'],
    'Defective': ['Error Free', 'Error Free', 'Defective', 'Error Free'],
    'Defective_2': ['Error Free', 'Error Free', 'Error Free', 'Error Free'],
    'Defective_3': ['Defective', 'Error Free', 'Defective', 'Error Free'],
    'Defective_4': ['Error Free', 'Defective', 'Error Free', 'Error Free'],})

# %%
# Display the first few rows of the dataframe to inspect the data
print(data)
# Out:
#         Country   Defective Defective_2 Defective_3 Defective_4
# 0  Phillippines  Error Free  Error Free   Defective  Error Free
# 1     Indonesia  Error Free  Error Free  Error Free   Defective
# 2         Malta   Defective  Error Free   Defective  Error Free
# 3         India  Error Free  Error Free  Error Free  Error Free

# %%
# Create a contingency table
contingency_table = pd.crosstab(data['Country'], data['Defective'])

# %%
# Perform Chi-square test
chi2, p_value, _, _ = chi2_contingency(contingency_table)

# %%
# Print the results
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p_value}")
# Out:
# Chi-square statistic: 4.0
# P-value: 0.26146412994911117

# %%
# Compare p-value to the significance level (e.g., 0.05)
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is an association between country and defective status.")
else:
    print("Fail to reject the null hypothesis. There is no association between country and defective status.")
# Out:
# Fail to reject the null hypothesis. There is no association between country and defective status.
